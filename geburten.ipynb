# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
df = pd.read_csv("geburten_bereinigt.csv", delimiter=",")
df.head()
# Out:
#    Stadtteilnummer Stadtteilname  Jahr Geburten
# 0               11      Altstadt  2015        .
# 1               11      Altstadt  2016       24
# 2               11      Altstadt  2017       16
# 3               11      Altstadt  2018        .
# 4               11      Altstadt  2019       20

# %%
df.columns = df.columns.str.lower()

# %%
df.geburten = df.geburten.replace("-",0)
df.geburten = df.geburten.replace(".",0)
df.geburten.unique()
# Out:
# array([0, '24', '16', '20', '18', '14', '19', '23', '32', '28', '17',
#        '15', '26', '151', '175', '143', '142', '133', '131', '402', '386',
#        '441', '466', '413', '432', '442', '422', '241', '257', '267',
#        '224', '244', '179', '225', '210', '169', '178', '148', '171',
#        '125', '140', '93', '119', '127', '115', '101', '105', '83', '271',
#        '324', '276', '340', '310', '338', '335', '348', '370', '358',
#        '326', '334', '325', '342', '296', '217', '223', '209', '195',
#        '174', '198', '177', '202', '228', '232', '205', '222', '235',
#        '212', '1', '86', '75', '49', '70', '69', '77', '64', '57', '25',
#        '431', '417', '439', '433', '424', '407', '377', '352', '331',
#        '343', '306', '311', '316', '41', '29', '31', '27', '199', '250',
#        '254', '229', '227', '234', '206', '117', '126', '122', '138',
#        '160', '136', '56', '66', '67', '61', '62', '68', '48', '53', '47',
# ...

# %%
df.geburten = df.geburten.astype("int64")
df.dtypes
# Out:
# stadtteilnummer     int64
# stadtteilname      object
# jahr                int64
# geburten            int64
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df, x="jahr", y="geburten")
plt.xlabel("Jahre")
plt.ylabel("Geburten pro Jahr")
# Out:
# Text(0, 0.5, 'Geburten pro Jahr')

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df, x="geburten")
# Out:
# <Axes: xlabel='geburten', ylabel='Count'>

# %%
plt.figure(figsize=(25,8))
box = sns.boxenplot(data=df, x="stadtteilname", y="geburten")
plt.xlabel("Stadtteile")
plt.ylabel("Geburten pro Stadtteil")
box.set_xticklabels(box.get_xticklabels(),
rotation=45,
horizontalalignment='right',
fontsize='x-large')
# Out:
# [Text(0, 0, 'Altstadt'),
#  Text(1, 0, 'Carlstadt'),
#  Text(2, 0, 'Stadtmitte'),
#  Text(3, 0, 'Pempelfort'),
#  Text(4, 0, 'Derendorf'),
#  Text(5, 0, 'Golzheim'),
#  Text(6, 0, 'Flingern Süd'),
#  Text(7, 0, 'Flingern Nord'),
#  Text(8, 0, 'Düsseltal'),
#  Text(9, 0, 'Friedrichstadt'),
#  Text(10, 0, 'Unterbilk'),
#  Text(11, 0, 'Hafen'),
#  Text(12, 0, 'Hamm'),
#  Text(13, 0, 'Volmerswerth'),
#  Text(14, 0, 'Bilk'),
#  Text(15, 0, 'Oberbilk'),
#  Text(16, 0, 'Flehe'),
#  Text(17, 0, 'Oberkassel'),
#  Text(18, 0, 'Heerdt'),
#  Text(19, 0, 'Lörick'),
#  Text(20, 0, 'Niederkassel'),
#  Text(21, 0, 'Stockum'),
#  Text(22, 0, 'Lohausen'),
#  Text(23, 0, 'Kaiserswerth'),
#  Text(24, 0, 'Wittlaer'),
#  Text(25, 0, 'Angermund'),
#  Text(26, 0, 'Kalkum'),
#  Text(27, 0, 'Lichtenbroich'),
#  Text(28, 0, 'Unterrath'),
#  Text(29, 0, 'Rath'),
#  Text(30, 0, 'Mörsenbroich'),
#  Text(31, 0, 'Gerresheim'),
#  Text(32, 0, 'Grafenberg'),
#  Text(33, 0, 'Ludenberg'),
#  Text(34, 0, 'Hubbelrath'),
# ...

# %%
df.jahr.unique()
df15 = df[(df.jahr == 2015)]
df16 = df[(df.jahr == 2016)]
df17 = df[(df.jahr == 2017)]
df18 = df[(df.jahr == 2018)]
df19 = df[(df.jahr == 2019)]
df20 = df[(df.jahr == 2020)]
df21 = df[(df.jahr == 2021)]
df22 = df[(df.jahr == 2022)]

# %%
geburten_total = df.groupby("stadtteilname").sum().reset_index()

# %%
sns.set_theme(style='dark')
plt.figure(figsize=(25,12))
box = sns.barplot(data=df15, x="stadtteilname", y="geburten", color="green",linewidth=2)
sns.barplot(data=df16, x="stadtteilname", y="geburten", color="lime",linewidth=2)
sns.barplot(data=df17, x="stadtteilname", y="geburten", color="seagreen",linewidth=2)
sns.barplot(data=df18, x="stadtteilname", y="geburten", color="mediumseagreen",linewidth=2)
sns.barplot(data=df19, x="stadtteilname", y="geburten", color="springgreen",linewidth=2)
sns.barplot(data=df20, x="stadtteilname", y="geburten", color="mintcream",linewidth=2)
sns.barplot(data=df21, x="stadtteilname", y="geburten", color="mediumspringgreen",linewidth=2)
sns.barplot(data=df22, x="stadtteilname", y="geburten", color="mediumaquamarine",linewidth=2)
df15l = mpatches.Patch(color="green", label="2015")
df16l = mpatches.Patch(color="lime", label="2016")
df17l = mpatches.Patch(color="seagreen", label="2017")
df18l = mpatches.Patch(color="mediumseagreen", label="2018")
df19l = mpatches.Patch(color="springgreen", label="2019")
df20l = mpatches.Patch(color="mintcream", label="2020")
df21l = mpatches.Patch(color="mediumspringgreen", label="2021")
df22l = mpatches.Patch(color="mediumaquamarine", label="2022")

plt.xlabel("Stadtteile")
plt.ylabel("Geburten pro Stadtteil")
plt.legend(handles=[df22l,df21l,df20l,df19l,df18l,df17l,df16l,df15l])
box.set_xticklabels(box.get_xticklabels(),
rotation=45,
horizontalalignment='right',
fontsize='x-large')
# Out:
# [Text(0, 0, 'Altstadt'),
#  Text(1, 0, 'Carlstadt'),
#  Text(2, 0, 'Stadtmitte'),
#  Text(3, 0, 'Pempelfort'),
#  Text(4, 0, 'Derendorf'),
#  Text(5, 0, 'Golzheim'),
#  Text(6, 0, 'Flingern Süd'),
#  Text(7, 0, 'Flingern Nord'),
#  Text(8, 0, 'Düsseltal'),
#  Text(9, 0, 'Friedrichstadt'),
#  Text(10, 0, 'Unterbilk'),
#  Text(11, 0, 'Hafen'),
#  Text(12, 0, 'Hamm'),
#  Text(13, 0, 'Volmerswerth'),
#  Text(14, 0, 'Bilk'),
#  Text(15, 0, 'Oberbilk'),
#  Text(16, 0, 'Flehe'),
#  Text(17, 0, 'Oberkassel'),
#  Text(18, 0, 'Heerdt'),
#  Text(19, 0, 'Lörick'),
#  Text(20, 0, 'Niederkassel'),
#  Text(21, 0, 'Stockum'),
#  Text(22, 0, 'Lohausen'),
#  Text(23, 0, 'Kaiserswerth'),
#  Text(24, 0, 'Wittlaer'),
#  Text(25, 0, 'Angermund'),
#  Text(26, 0, 'Kalkum'),
#  Text(27, 0, 'Lichtenbroich'),
#  Text(28, 0, 'Unterrath'),
#  Text(29, 0, 'Rath'),
#  Text(30, 0, 'Mörsenbroich'),
#  Text(31, 0, 'Gerresheim'),
#  Text(32, 0, 'Grafenberg'),
#  Text(33, 0, 'Ludenberg'),
#  Text(34, 0, 'Hubbelrath'),
# ...

# %%
#plt.figure(figsize=(20,10))
#plt.subplot(2,4,1)
#sns.histplot(data=df15, x="geburten", color="green")
#plt.subplot(2,4,2)
#sns.histplot(data=df16, x="geburten", color="lime")
#plt.subplot(2,4,3)
#sns.histplot(data=df17, x="geburten", color="seagreen")
#plt.subplot(2,4,4)
#sns.histplot(data=df18, x="geburten", color="mediumseagreen")
#plt.subplot(2,4,5)
#sns.histplot(data=df19, x="geburten", color="springgreen")
#plt.subplot(2,4,6)
#sns.histplot(data=df20, x="geburten", color="yellowgreen")
#plt.subplot(2,4,7)
#sns.histplot(data=df21, x="geburten", color="mediumspringgreen")
#plt.subplot(2,4,8)
#sns.histplot(data=df22, x="geburten", color="mediumaquamarine")

# %%
sns.set_theme(style="dark")
plt.figure(figsize=(25,8))
geburten_total = df.groupby("stadtteilname").sum().reset_index()


unique_stadt = df.stadtteilname.unique()
plt.figure(figsize=(25,8))
sorted_group= geburten_total.sort_values(['geburten'], ascending=False).reset_index(drop=False)
print(sorted_group.head())
print(sorted_group.stadtteilname)



sorted_bar = sns.barplot(x=sorted_group.stadtteilname, y=sorted_group.geburten)
plt.xlabel("Stadtteile")
plt.ylabel("Anzahl gesamter Geburten 2015 - 2022")
sorted_bar.set_xticklabels(sorted_bar.get_xticklabels(),
rotation=45,horizontalalignment='right',fontsize='x-large')


print(geburten_total.head(10))
# Out:
#    index  stadtteilname  stadtteilnummer   jahr  geburten
# 0     37     Pempelfort              112  16148      3404
# 1      3           Bilk              288  16148      3370
# 2      6      Düsseltal              184  16148      2699
# 3     35       Oberbilk              296  16148      2641
# 4      9  Flingern Nord              176  16148      2518
# 0         Pempelfort
# 1               Bilk
# 2          Düsseltal
# 3           Oberbilk
# 4      Flingern Nord
# 5              Eller
# 6            Wersten
# 7         Gerresheim
# 8          Derendorf
# 9         Oberkassel
# 10         Unterbilk
# 11              Rath
# 12      Mörsenbroich
# 13    Friedrichstadt
# 14            Garath
# 15           Hassels
# 16           Benrath
# 17         Unterrath
# 18          Golzheim
# 19        Stadtmitte
# 20        Holthausen
# 21            Heerdt
# 22        Lierenfeld
# 23      Flingern Süd
# 24         Ludenberg
# 25        Vennhausen
# 26         Urdenbach
# ...

# %%
geburten_total = df.groupby("stadtteilname").sum().reset_index()

gdf15 = df15.groupby("stadtteilname").sum().reset_index() 
gdf15 = gdf15.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf16 = df16.groupby("stadtteilname").sum().reset_index() 
gdf16 = gdf16.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf17 = df17.groupby("stadtteilname").sum().reset_index() 
gdf17 = gdf17.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf18 = df18.groupby("stadtteilname").sum().reset_index() 
gdf18 = gdf18.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf19 = df19.groupby("stadtteilname").sum().reset_index() 
gdf19 = gdf19.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf20 = df20.groupby("stadtteilname").sum().reset_index() 
gdf20 = gdf20.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf21 = df21.groupby("stadtteilname").sum().reset_index() 
gdf21 = gdf21.sort_values(["geburten"], ascending=False).reset_index(drop=False)
gdf22 = df22.groupby("stadtteilname").sum().reset_index() 
gdf22 = gdf22.sort_values(["geburten"], ascending=False).reset_index(drop=False)


plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.subplots_adjust(wspace = 0.4, hspace=0.4)

sns.barplot(data=gdf15.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2015")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,2)
sns.barplot(data=gdf16.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2016")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,3)
sns.barplot(data=gdf17.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2017")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,4)
sns.barplot(data=gdf18.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2018")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,5)
sns.barplot(data=gdf19.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2019")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,6)
sns.barplot(data=gdf20.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2020")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,7)
axa = sns.barplot(data=gdf21.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2021")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")
plt.subplot(2,4,8)
ax = sns.barplot(data=gdf22.head(3), x="stadtteilname", y="geburten")
plt.title("Geburten 2022")
plt.xlabel("Geburten in diesem Jahr")
plt.ylabel("Stadtteil")

for container in axa.containers:
    ax.bar_label(container, fmt='%.1f')

# %%
#Prozentuale Entwicklung der einzelnen Top 3 Stadtteile von Jahr zu Jahr
